# %% [markdown]
# <a href="https://colab.research.google.com/github/eerenkurt/ml-studies/blob/main/10-knn-and-ensemble-tuning/heart_disease_classifier_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('heart.csv')

# %%
df.head(3)
# Out:
#    age  sex  cp  trtbps  chol  fbs  ...  exng  oldpeak  slp  caa  thall  output
# 0   63    1   3     145   233    1  ...     0      2.3    0    0      1       1
# 1   37    1   2     130   250    0  ...     0      3.5    0    0      2       1
# 2   41    0   1     130   204    0  ...     0      1.4    2    0      2       1
#
# [3 rows x 14 columns]

# %%
y = df["output"]
x = df.drop("output",axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.7,random_state=42)

# %%
dt = DecisionTreeClassifier()
model = dt.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.6807511737089202

# %%
rf = RandomForestClassifier(n_estimators=200)
model = rf.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.8215962441314554

# %%
rf = xgb.XGBClassifier()
model = rf.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.7981220657276995

# %%
df.shape
# Out:
# (303, 14)

# %%
insan = df.sample().drop("output",axis=1).values

# %%
model.predict(insan)
# Out:
# array([1])
