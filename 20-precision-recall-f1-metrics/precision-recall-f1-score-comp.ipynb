# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/aldinwhyudii/student-depression-and-lifestyle-100k-data/student_lifestyle_100k.csv

# %%
df = pd.read_csv('/kaggle/input/datasets/aldinwhyudii/student-depression-and-lifestyle-100k-data/student_lifestyle_100k.csv')
df.drop('Student_ID',axis=1)
df.head(3)
# Out:
#    Student_ID  Age  Gender   Department  CGPA  Sleep_Duration  Study_Hours  \
# 0        1001   22  Female      Science  3.50             7.3          3.3
# 1        1002   20    Male  Engineering  2.72             5.5          7.2
# 2        1003   20    Male      Medical  3.01             5.4          2.3
#
#    Social_Media_Hours  Physical_Activity  Stress_Level  Depression
# 0                 3.4                114             5       False
# 1                 6.0                142             2       False
# 2                 1.8                137             3       False

# %%
df = pd.get_dummies(df,columns=['Gender','Department'],drop_first=True)

# %%
df.head(3)
# Out:
#    Student_ID  Age  CGPA  Sleep_Duration  Study_Hours  Social_Media_Hours  \
# 0        1001   22  3.50             7.3          3.3                 3.4
# 1        1002   20  2.72             5.5          7.2                 6.0
# 2        1003   20  3.01             5.4          2.3                 1.8
#
#    Physical_Activity  Stress_Level  Depression  Gender_Male  \
# 0                114             5       False        False
# 1                142             2       False         True
# 2                137             3       False         True
#
#    Department_Business  Department_Engineering  Department_Medical  \
# 0                False                   False               False
# 1                False                    True               False
# 2                False                   False                True
#
#    Department_Science
# 0                True
# 1               False
# 2               False

# %%
y = df['Depression']
x = df.drop('Depression',axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.9,random_state=42)

# %%
rf = RandomForestClassifier()
model = rf.fit(x_train,y_train)

# %%
model.score(x_test,y_test)
# Out:
# 0.8998

# %%
df['Depression'].value_counts()
# Out:
# Depression
# False    89938
# True     10062
# Name: count, dtype: int64

# %%
sonuc = model.predict(x_test)
dfs = pd.DataFrame()
dfs['sonuc']=sonuc
dfs['gercek']=y_test.values
dfs['sonuc'].value_counts()
# Out:
# sonuc
# False    9953
# True       47
# Name: count, dtype: int64

# %%
dfs['gercek'].value_counts()
# Out:
# gercek
# False    9009
# True      991
# Name: count, dtype: int64

# %%
dfs['truebil'] = (dfs['gercek']==True) & (dfs['sonuc']==True)

# %%
dfs['truebil'].value_counts()
# Out:
# truebil
# False    9982
# True       18
# Name: count, dtype: int64

# %%
18/51
# Out:
# 0.35294117647058826

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
precision = precision_score(dfs['gercek'],dfs['sonuc'])

# %%
18/991
# Out:
# 0.018163471241170535

# %%
recall = recall_score(dfs['gercek'],dfs['sonuc'])

# %%
2*(precision*recall)/(precision+recall)
# Out:
# 0.034682080924855495

# %%
f1 = f1_score(dfs['gercek'],dfs['sonuc'])
