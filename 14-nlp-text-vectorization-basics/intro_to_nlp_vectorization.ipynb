# %% [markdown]
# <a href="https://colab.research.google.com/github/eerenkurt/ml-studies/blob/main/14-nlp-text-vectorization-basics/intro_to_nlp_vectorization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.DataFrame()

# %%
df["cumleler"] = ["ali bak","ali ata bak","bak ali bak","ali güzel ata bak","ışık ılık süt iç","ışık süt iç","iç ışık iç"]

# %%
cv = CountVectorizer(max_features=4)

# %%
a = cv.fit_transform(df["cumleler"])

# %%
x = a.toarray()

# %%
cv.get_feature_names_out()
# Out:
# array(['ali', 'bak', 'iç', 'ışık'], dtype=object)

# %%
# stop words

# ne mesela fakat gibi
