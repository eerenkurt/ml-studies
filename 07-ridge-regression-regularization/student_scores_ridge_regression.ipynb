# %% [markdown]
# <a href="https://colab.research.google.com/github/eerenkurt/ml-studies/blob/main/07-ridge-regression-regularization/student_scores_ridge_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ridge regresyon overfitting (Aşırı öğrenme durumları için kullanılır)
# Ridge regresyon sayesinde bias ve varyans arasındaki dengeyi sağlayabiliriz
# Ridge regresyonda katsayılar üzerinde regülasyon yapılıyor
# Ridge regresyonda katsayılar küçülür ama sıfır olmaz. Features öz nitelik azalmaz
# Ridge regresyonda cezalar karasi ile orantılı
# Ridge regresyon 12

# %%
# y = a1 * x1 + a2 * x2 + ... + b + alfa * (katsayılar toplamı)**2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression ,Ridge

# %%
df = pd.read_csv("student.csv")

# %%
df.head(3)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27

# %%
y = df["Scores"]
x = df[["Hours"]]

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(8,8))
plt.scatter(x,y)
plt.show()

# %%
lr = LinearRegression()
model = lr.fit(x,y)
model.score(x,y)
# Out:
# 0.9529481969048356

# %%
r = Ridge(alpha=1)
model = r.fit(x,y)
model.score(x,y)
# Out:
# 0.9529080290200403
